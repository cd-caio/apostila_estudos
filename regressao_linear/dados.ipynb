# %%
import pandas as pd
import plotly.express as px

# %%
df = pd.read_csv("./train.csv")

# %%
df[["GarageArea", "SalePrice", "LotArea"]][(df["LotArea"] < 20000) & (df["GarageArea"] > 1)].corr()
# Out:
#             GarageArea  SalePrice   LotArea
# GarageArea    1.000000   0.628305  0.324906
# SalePrice     0.628305   1.000000  0.402428
# LotArea       0.324906   0.402428  1.000000

# %%
fig = px.scatter(df, x="LotArea", y="SalePrice")
fig.show()

# %%
df[(df["LotArea"] < 20000) & (df["GarageArea"] > 1)][["GarageArea", "SalePrice", "LotArea"]].to_csv("train_data_final.csv")
